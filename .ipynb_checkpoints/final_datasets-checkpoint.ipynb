# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Prepare and display NSW data

# %%
# Prepare NSW data
data = pd.read_csv('Fabi/master_dataset.csv', sep=',')

# %%
class CreateNSWDataset():
    def __init__(self, data, n_teachers=54000, school_teacher_ratio=1.2, teacher_per_school=15.,
                 std_dev_teacher_per_school=3., min_teachers_per_school=5, p_rural=0.3, p_car=0.7, p_experienced=0.4):
        self.data = data
        self.n_teachers = int(n_teachers / 1.05)
        self.n_schools = len(data)
        #self.n_schools = int(n_teachers * school_teacher_ratio / teacher_per_school)        
        self.teacher_per_school = teacher_per_school
        self.std_dev_teacher_per_school = std_dev_teacher_per_school
        self.min_teachers_per_school = min_teachers_per_school
        self.p_rural = p_rural
        self.p_car = p_car
        self.p_experienced = p_experienced
        
        self.big_cities = np.array([[151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.209444, -33.865],
                       [151.75, -32.916667],
                       [151.2, -33.3],
                       [150.893915, -34.427243],
                       [151.55, -32.716667],
                       [150.3, -33.7],
                       [153.55, -29.183333],
                       [147.368889, -35.118889],
                       [150.0, -37.5]])
        
    def _createTeachers_v2(self):
        loc_school = np.array([data['Longitude'], data['Latitude']]).T
        for _ in range(10):
            loc_school = np.concatenate((loc_school, self.big_cities))
        loc_school = np.resize(loc_school, (self.n_teachers,2))
        x_location = loc_school[:,0] + np.random.normal(0, 0.3, size=self.n_teachers)
        y_location = loc_school[:,1] + np.random.normal(0, 0.3, size=self.n_teachers)
        rural = np.random.choice([0, 1], p=[1 - self.p_rural, self.p_rural], size=self.n_teachers)
        car = np.random.choice([0, 1], p=[1 - self.p_car, self.p_car], size=self.n_teachers)
        experienced = np.random.choice([0, 1], p=[1 - self.p_experienced, self.p_experienced], size=self.n_teachers)
        teachers = {'x_location': x_location,
                    'y_location': y_location,
                    'rural': rural,
                    'car': car,
                    'experienced': experienced,
                    }

        return teachers
    
    def _createSchools(self):
        loc_school = np.array([data['Longitude'], data['Latitude']]).T
        x_location = loc_school[:,0]
        y_location = loc_school[:,1]
        rural = np.random.choice([0, 1], p=[1 - self.p_rural, self.p_rural], size=len(loc_school))
        n_teachers = self.data["latest_year_enrolment_FTE"] / self.teacher_per_school
        
        schools = {'ID': range(len(loc_school)),
                   'x_location': x_location,
                   'y_location': y_location,
                   'rural': rural,
                   'n_teachers': n_teachers,
                   }

        return schools

    def make_dataset(self):
        teachers = pd.DataFrame(self._createTeachers_v2())
        schools = pd.DataFrame(self._createSchools())

        return teachers, schools

# %%
DatasetSampler = CreateNSWDataset(data)
teachers, schools = DatasetSampler.make_dataset()

# %%
n_students = data["latest_year_enrolment_FTE"]

plt.figure(figsize=(14,10))
plt.scatter(schools["x_location"], schools["y_location"], s = n_students/3, label="schools with schoolsize")
plt.scatter(teachers["x_location"], teachers["y_location"], label="teachers", s=0.1)
plt.legend()
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Prepare and display GER data

# %%
# Prepare GER data
data_ger = pd.read_csv('Fabi/de.csv', sep=',')
data_ger.drop(np.arange(592,603), inplace=True)

# %%
class CreateGERDataset():
    def __init__(self, data, n_teachers=90000, school_teacher_ratio=1.2, teacher_per_school=15.,
                 std_dev_teacher_per_school=3., min_teachers_per_school=5, p_rural=0.3, p_car=0.7, p_experienced=0.4):
        self.data = data
        self.n_teachers = int(n_teachers / 1.05)
        self.n_schools = len(data)
        #self.n_schools = int(n_teachers * school_teacher_ratio / teacher_per_school)        
        self.teacher_per_school = teacher_per_school
        self.std_dev_teacher_per_school = std_dev_teacher_per_school
        self.min_teachers_per_school = min_teachers_per_school
        self.p_rural = p_rural
        self.p_car = p_car
        self.p_experienced = p_experienced
    
   
    def _createTeachers(self):
        loc_school = np.array([self.data['lng'], self.data['lat']]).T
        for _ in range(10):
            loc_school = np.concatenate((loc_school, loc_school[0:40]))
        loc_school = np.resize(loc_school, (self.n_teachers,2))
        x_location = loc_school[:,0] + np.random.normal(0, 0.3, size=self.n_teachers)
        y_location = loc_school[:,1] + np.random.normal(0, 0.3, size=self.n_teachers)
        rural = np.random.choice([0, 1], p=[1 - self.p_rural, self.p_rural], size=self.n_teachers)
        car = np.random.choice([0, 1], p=[1 - self.p_car, self.p_car], size=self.n_teachers)
        experienced = np.random.choice([0, 1], p=[1 - self.p_experienced, self.p_experienced], size=self.n_teachers)
        teachers = {'x_location': x_location,
                    'y_location': y_location,
                    'rural': rural,
                    'car': car,
                    'experienced': experienced,
                    }
        return teachers
    
    def _createSchools(self):
        loc_school = np.array([self.data['lng'], self.data['lat']]).T
        x_location = loc_school[:,0]
        y_location = loc_school[:,1]
        rural = np.random.choice([0, 1], p=[1 - self.p_rural, self.p_rural], size=len(loc_school))
        n_teachers = self.data["population"] * 0.18 / self.teacher_per_school
        
        schools = {'ID': range(len(loc_school)),
                   'x_location': x_location,
                   'y_location': y_location,
                   'rural': rural,
                   'n_teachers': n_teachers,
                   }

        return schools

    def make_dataset(self):
        teachers = pd.DataFrame(self._createTeachers())
        schools = pd.DataFrame(self._createSchools())

        return teachers, schools

# %%
DatasetSampler = CreateGERDataset(data_ger)
teachers, schools = DatasetSampler.make_dataset()

# %%
n_students_ger = data_ger["population"] * 0.18 /1000

plt.figure(figsize=(8,10))
plt.scatter(schools["x_location"], schools["y_location"], s=n_students_ger, label="schools with schoolsize")
plt.scatter(teachers["x_location"], teachers["y_location"], label="teachers", s=0.05)
plt.xticks([])
plt.yticks([])
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier

school_per_cluster = 8
n_iterations = 1
min_differences = []
variances = []
# to do: have to add noise to x and y!!!!
scal = np.random.normal(loc=0., scale=0.1, size=(n_iterations, len(teachers), 2))

def custom_loss(x, y):
    return np.sum((x - y)**2)

# Finding the best random seed for kmeans
for i in range(n_iterations):
    # Kmeans for School-to-Cluster
    X_train = np.array(schools[['x_location', 'y_location']])
    labels = [i for i in range((DatasetSampler.n_schools // school_per_cluster))]
    kmeans = KMeans(n_clusters=(DatasetSampler.n_schools // school_per_cluster), random_state=i)
    preds = kmeans.fit_predict(X_train, labels)
    means = kmeans.cluster_centers_
    cluster_labels = kmeans.labels_
    schools['cluster'] = cluster_labels
    
    # KNN for Teacher-to-Cluster
    knn = KNeighborsClassifier(n_neighbors=1, metric=custom_loss)
    X_train = means
    y_train = labels
    knn.fit(X_train, y_train)
    X_test = np.array(teachers[['x_location', 'y_location']]) + scal[i]
    preds = knn.predict(X_test)
    teachers['cluster'] = preds
    
    # Apply Metric
    teacher_demand = schools.groupby(by='cluster')['n_teachers'].sum()
    teacher_supply = teachers.groupby(by='cluster')['x_location'].count()
    teachers_difference = teacher_supply - teacher_demand
    teachers_difference_pct = teachers_difference / teacher_demand
    min_difference = min(teachers_difference_pct)
    min_differences.append(min_difference)
    variances.append(teachers_difference_pct.std()**2)

# %%
# KNN for Teacher-to-Cluster
knn = KNeighborsClassifier(n_neighbors=1, metric=custom_loss)
X_train = means
y_train = labels
knn.fit(X_train, y_train)
X_test = np.array(teachers[['x_location', 'y_location']])
preds = knn.predict(X_test + scal[i])
teachers['cluster'] = preds

plt.figure(figsize=(15,10))
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds, cmap='rainbow', label='Teachers')
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, linewidth=10., cmap='rainbow', label='School clusters')

plt.legend(bbox_to_anchor=(1.05, 1, 0, 0), fontsize=16)
plt.show()

# %%
# Do optimized run
best_iteration = np.argmax(np.array(min_differences))
#best_iteration = np.argmin(np.array(variances))
X_train = np.array(schools[['x_location', 'y_location']])
labels = [i for i in range((DatasetSampler.n_schools // school_per_cluster))]
kmeans = KMeans(n_clusters=(DatasetSampler.n_schools // school_per_cluster), random_state=best_iteration)
preds = kmeans.fit_predict(X_train, labels)
means = kmeans.cluster_centers_
schools['cluster'] = preds

#plt.figure(figsize=(15,10))
#plt.scatter(X_train[:, 0], X_train[:, 1], c=preds, cmap='rainbow',)
#plt.scatter(means[:, 0], means[:, 1], c=labels, linewidth=10., cmap='rainbow')
#plt.show()
fig, ax = plt.subplots(figsize=(15, 10))
scatter = ax.scatter(X_train[:, 0], X_train[:, 1], c=preds, label='Schools')
ax.scatter(means[:, 0], means[:, 1], label='School clusters', c=labels, linewidth=10.)
plt.legend(bbox_to_anchor=(1.05, 1, 0, 0), fontsize=16)
plt.show()

# %%
# Do optimized run
best_iteration = np.argmax(np.array(min_differences))
#best_iteration = np.argmin(np.array(variances))
X_train = np.array(schools[['x_location', 'y_location']])
labels = [i for i in range((DatasetSampler.n_schools // school_per_cluster))]
kmeans = KMeans(n_clusters=(DatasetSampler.n_schools // school_per_cluster), random_state=best_iteration)
preds = kmeans.fit_predict(X_train, labels)
means = kmeans.cluster_centers_
schools['cluster'] = preds

knn = KNeighborsClassifier(n_neighbors=1, metric=custom_loss)
X_train = means
y_train = labels
knn.fit(X_train, y_train)
X_test = np.array(teachers[['x_location', 'y_location']])
preds = knn.predict(X_test + scal[i])
teachers['cluster'] = preds

teachers['school'] = np.nan

for cluster in range(DatasetSampler.n_schools // school_per_cluster):
    cluster_teachers = teachers[teachers['cluster'] == cluster]
    cluster_schools = schools[schools['cluster'] == cluster]
    
    knn = KNeighborsClassifier(n_neighbors=1, metric=custom_loss)
    X_train = np.array(cluster_schools[['x_location', 'y_location']])
    
    y_train = cluster_schools['ID']
    
    knn.fit(X_train, y_train)
    
    X_test = np.array(cluster_teachers[['x_location', 'y_location']])
    teacher_schools = knn.predict(X_test)
    
    teachers.loc[teachers['cluster'] == cluster, 'school'] = teacher_schools

teacher_positions = np.array(teachers[['x_location', 'y_location']])
school_positions = np.array(schools[['x_location', 'y_location']])

# %%
plt.figure(figsize=(8, 10))
plt.scatter(teacher_positions[:,0], teacher_positions[:,1], c=teachers['school'], cmap='rainbow', label='Teachers')
plt.scatter(school_positions[:,0], school_positions[:,1], c=schools['ID'], linewidth=10, cmap='rainbow', label='Schools')
plt.legend(bbox_to_anchor=(1.05, 1, 0, 0), fontsize=16)
plt.show()

# %%
# Fill DataFrame
schools_df = pd.DataFrame({
                           'teacher_demand': schools['n_teachers'],
                           'teacher_supply': teachers.groupby(by='school')['x_location'].count(),
                           })
schools_df['teachers_difference'] = schools_df['teacher_supply'] - schools_df['teacher_demand']

schools_df['teachers_difference_pct'] = schools_df['teachers_difference'] / schools_df['teacher_demand']

# Absolute Difference
sns.distplot(schools_df['teachers_difference'], bins=50)
plt.figure()
sns.distplot(schools_df['teachers_difference_pct'], bins=50)
plt.figure()
schools_df['avg experience'] = teachers.groupby(by='school')['experienced'].mean()
sns.distplot(schools_df['avg experience'], bins=50)
